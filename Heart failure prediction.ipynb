# %% [markdown]
# ## Overview

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# ## Anaylze the numeric values using displot

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
sns.displot(data=df,x='Age',kde=True)#for distribution
#KDE it help to draw a line..

# %%
sns.distplot(df['Age'],kde=True,hist=True)
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_8428\3448643953.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],kde=True,hist=True)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Age'],kde=True,hist=True,rug=True)
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_23136\4212609025.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],kde=True,hist=True,rug=True)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Age'],bins=10)
#it divides thw whole dataset in 10 equal parts
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_8428\3709893901.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],bins=10)
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## Categorical anaylzse

# %%
sns.distplot(df['RestingBP'],kde=True,hist=True,rug=True)
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_8428\287188667.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['RestingBP'],kde=True,hist=True,rug=True)
# <Axes: xlabel='RestingBP', ylabel='Density'>

# %%
sns.distplot(df['Cholesterol'],kde=True,hist=True,rug=True)
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_23136\784263788.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Cholesterol'],kde=True,hist=True,rug=True)
# <Axes: xlabel='Cholesterol', ylabel='Density'>

# %%
sns.distplot(df['MaxHR'],kde=True,hist=True,rug=True)
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_23136\2350004782.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['MaxHR'],kde=True,hist=True,rug=True)
# <Axes: xlabel='MaxHR', ylabel='Density'>

# %% [markdown]
# ## Pie chart for categorial

# %%
df.groupby('Sex').size().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: >

# %%
df.groupby('ChestPainType').size().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: >

# %%
df.groupby('RestingECG').size().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: >

# %%
df.groupby('ST_Slope').size().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: >

# %%
df.groupby('HeartDisease').size().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: >

# %% [markdown]
# ## Violin plot

# %%
# its uses when we have multiple columns at same time anaylsis

# %%
sns.violinplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.violinplot(x=df['Sex'],y=df['HeartDisease'])
# Out:
# <Axes: xlabel='Sex', ylabel='HeartDisease'>

# %%
sns.violinplot(y=df['Age'],x=df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
sns.violinplot(y=df['Cholesterol'],x=df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %%
sns.violinplot(y=df['Age'],x=df['RestingECG'])
# Out:
# <Axes: xlabel='RestingECG', ylabel='Age'>

# %% [markdown]
# ## Correlation(Heatmap)

# %%
df.corr(numeric_only=True)
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %% [markdown]
# ## Joint Plot to find the correlation between columns

# %%
sns.jointplot(x='Age',y='MaxHR',data=df,kind="hex")

# %%
sns.jointplot(x='Age',y='Age',data=df)

# %%
sns.jointplot(x='Cholesterol',y='Oldpeak',data=df)

# %%
sns.jointplot(x='Age',y='MaxHR',data=df,kind="reg")

# %%
sns.jointplot(x='Cholesterol',y='FastingBS',data=df,kind="reg")

# %%
sns.jointplot(x='HeartDisease',y='MaxHR',data=df,kind="reg")
#this is correltaed because line reg. passes through data

# %% [markdown]
# ## Pair plot

# %%
sns.pairplot(df)
